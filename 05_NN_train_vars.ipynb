# %%
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold, StratifiedKFold
import tensorflow as tf
import seaborn as sns
import gc

# %%
df_train = pd.read_csv('train_with_counts.csv')
df_test = pd.read_csv('test_with_counts.csv')

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import Adam, SGD
from keras.layers import Dropout, BatchNormalization
from keras.layers.advanced_activations import LeakyReLU, PReLU, ELU
from keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
# Funcion que devuelve grid para graficar resultado de LGBM
def get_df_grid(train, var_idx):
    var_i = 'var_' + str(var_idx)
    mn,mx = train[:, 0].min(), train[:, 0].max()
    mnFE = train[:, 1].min()
    mxFE = train[:, 1].max()
    step = 50
    stepB = 15
    w = (mx-mn)/step
    x = w * (np.arange(0,step)+0.5) + mn
    x2 = np.array([])
    for i in range(stepB):
        x2 = np.concatenate([x,x2])
    # 
    df_grid = pd.DataFrame({var_i:x2})
    df_grid[var_i+'_FE'] = mnFE + (mxFE-mnFE)/(stepB-1) * (df_grid.index//step)
    df_grid['pred'] = 0
    return df_grid

# %%
def auc(y_true, y_pred):
    f1 = lambda: tf.constant(0, dtype=tf.float64)
    f2 = lambda: tf.py_func(roc_auc_score, (y_true, y_pred), tf.double)
    
    r = tf.case([(tf.equal(tf.reduce_sum(y_true), tf.constant(0, dtype=tf.float32)), f1),
                 (tf.equal(tf.reduce_sum(tf.subtract(tf.ones_like(y_true), y_true)), tf.constant(0, dtype=tf.float32)), f1)
                ], default=f2)
    return r

# %%
def get_model(input_shape, lr=0.001, decay=1e-3, hidden_units=100):
    model = Sequential()
    model.add(Dense( hidden_units, input_shape=(input_shape,)))
    # model.add(BatchNormalization())
    model.add(PReLU())
    # model.add(ELU())
    # model.add(Dense( 100, input_shape=(X_train.shape[1],), activation='relu'))
    # model.add(Dense( 50, input_shape=(X_train.shape[1],), activation='relu'))
    # model.add(BatchNormalization())
    # model.add(Dropout(0.5))
    model.add(Dense( 1, input_shape=(input_shape,), activation='sigmoid'))
    model.compile(Adam(lr=lr, decay=decay), loss='binary_crossentropy', metrics=[auc])
    return model

# %%
best_model_file_name = 'best_model.h5'

# %%
# var_0   Valid aucroc: 0.548506243183567
# var_198 Valid aucroc: 0.55081

# %%
def train_var(X_train, X_test, y_train, var_, verbose=1):
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    val_predictions = np.zeros(len(y_train))
    test_preds = np.zeros(len(X_test))
    for fold, (trn_idx, val_idx) in enumerate(skf.split(X_train, y_train)):
        print(f'################### Fold {fold+1} ########################')
        es = EarlyStopping(monitor='val_auc', patience=10, mode='max', verbose=verbose)
        mc = ModelCheckpoint(best_model_file_name, monitor='val_auc', mode='max', verbose=verbose, save_best_only=True)
        model = get_model(X_train.shape[1], lr=0.001, decay=0, hidden_units=1000)
        # First train
        model.fit(X_train[trn_idx], y_train[trn_idx], 
              epochs=50, batch_size=400, 
              verbose=0,
              callbacks = [es, mc],
              validation_data=(X_train[val_idx], y_train[val_idx]))
#         del model, es, mc
#         model = get_model(X_train.shape[1], lr=0.0001, decay=0, hidden_units=1000)
#         model.load_weights(best_model_file_name)
#         # Second train
#         es = EarlyStopping(monitor='val_auc', patience=10, mode='max', verbose=verbose)
#         mc = ModelCheckpoint(best_model_file_name, monitor='val_auc', mode='max', verbose=verbose, save_best_only=True)
#         model.fit(X_train[trn_idx], y_train[trn_idx], 
#               epochs=50, batch_size=400, 
#               verbose=0,
#               callbacks = [es, mc],
#               validation_data=(X_train[val_idx], y_train[val_idx]))
        model.load_weights(best_model_file_name)
        fold_val_preds = model.predict_proba(X_train[val_idx], verbose=1)
        fold_train_preds = model.predict_proba(X_train[trn_idx], verbose=1)
        val_predictions[val_idx] = fold_val_preds.reshape(-1)
        print('Train auc', roc_auc_score(y_train[trn_idx], fold_train_preds))
        print('Valid auc', roc_auc_score(y_train[val_idx], fold_val_preds))
        test_preds += model.predict(X_test).reshape(-1)/5.0
        del model, es, mc
        gc.collect()
    del X_train, X_test, skf
    print('Valid aucroc:', roc_auc_score(y_train, val_predictions))
    return test_preds, val_predictions

# %%
# Normalize
y_train = df_train[['target']].values
df_train_X = df_train.drop(columns=['ID_code', 'target'])
df_train_X_normalized = (df_train_X - df_train_X.mean(axis=0))/df_train_X.std(axis=0)
df_test_X = df_test.drop(columns=['ID_code'])
df_test_X_normalized = (df_test_X - df_test_X.mean(axis=0))/df_test_X.std(axis=0)

# %%
# test_preds, val_predictions = train_var(df_train_X_normalized, df_test_X_normalized, y_train, 198, verbose=1)

# %%
all_off_filename = 'all_oof_NN_v2.npy'
all_test_pred_filename = 'all_test_preds_NN_v2.npy'

all_oof = np.load(all_off_filename)
unique_values, unique_indexes, unique_inverse, unique_counts  = np.unique(all_oof[0, :], return_counts=True, return_index=True, return_inverse=True)
errors = np.where(unique_counts[unique_inverse]>1)[0]
print(errors)
# Out:
# [ 43  44  73  74 150 151]

# %%
# [ 61  62  63  83  84  92  93  97  98  99 100 104 105 149 150 165 166]

# %%
import os #34, 43, #73

# %%
num_vars = 200
# SAVE OUT-OF-FOLD PREDICTIONS
if os.path.exists(all_off_filename):
    all_oof = np.load(all_off_filename)
else:
    all_oof = np.zeros((len(df_train),num_vars))
# SAVE TEST PREDICTIONS
if os.path.exists(all_test_pred_filename):
    all_test_preds = np.load(all_test_pred_filename)
else:
    all_test_preds = np.zeros((len(df_test),num_vars))


for i in range(num_vars):
    if all_oof[:, i].sum() == 0 or i in errors:
        print(f'################################################################')
        print(f'########################### VAR {i} ##############################')
        print(f'################################################################')
        print()
        features = [f'var_{i}', f'var_{i}_FE']
        X_train = df_train_X_normalized[features].values
        X_test = df_test_X_normalized[features].values
        # %time test_preds, val_predictions = train_var(X_train, X_test, y_train, i, verbose=0)
        all_oof[:, i] = val_predictions
        all_test_preds[:, i] = test_preds
        np.save(all_off_filename, all_oof)
        np.save(all_test_pred_filename, all_test_preds)
        print()
    else: 
        print(f'VAR {i} Already calculated', end = ' / ')
# Out:
# VAR 0 Already calculated / VAR 1 Already calculated / VAR 2 Already calculated / VAR 3 Already calculated / VAR 4 Already calculated / VAR 5 Already calculated / VAR 6 Already calculated / VAR 7 Already calculated / VAR 8 Already calculated / VAR 9 Already calculated / VAR 10 Already calculated / VAR 11 Already calculated / VAR 12 Already calculated / VAR 13 Already calculated / VAR 14 Already calculated / VAR 15 Already calculated / VAR 16 Already calculated / VAR 17 Already calculated / VAR 18 Already calculated / VAR 19 Already calculated / VAR 20 Already calculated / VAR 21 Already calculated / VAR 22 Already calculated / VAR 23 Already calculated / VAR 24 Already calculated / VAR 25 Already calculated / VAR 26 Already calculated / VAR 27 Already calculated / VAR 28 Already calculated / VAR 29 Already calculated / VAR 30 Already calculated / VAR 31 Already calculated / VAR 32 Already calculated / VAR 33 Already calculated / VAR 34 Already calculated / VAR 35 Already calculated / VAR 36 Already calculated / VAR 37 Already calculated / VAR 38 Already calculated / VAR 39 Already calculated / VAR 40 Already calculated / VAR 41 Already calculated / VAR 42 Already calculated / ################################################################
# ########################### VAR 43 ##############################
# ################################################################
#
# ################### Fold 1 ########################
# 40001/40001 [==============================] - 0s 7us/step
# 159999/159999 [==============================] - 1s 6us/step
# Train auc 0.5274085390944983
# Valid auc 0.5194655526458754
# ################### Fold 2 ########################
# 40001/40001 [==============================] - 0s 7us/step
# 159999/159999 [==============================] - 1s 6us/step
# Train auc 0.5269049912481746
# Valid auc 0.5263288937320567
# ################### Fold 3 ########################
# 40000/40000 [==============================] - 0s 7us/step
# 160000/160000 [==============================] - 1s 6us/step
# Train auc 0.5236819163748666
# Valid auc 0.5345082363336182
# ################### Fold 4 ########################
# 39999/39999 [==============================] - 0s 8us/step
# 160001/160001 [==============================] - 1s 7us/step
# Train auc 0.5268374754432442
# Valid auc 0.5265933418540976
# ################### Fold 5 ########################
# 39999/39999 [==============================] - 0s 7us/step
# 160001/160001 [==============================] - 1s 7us/step
# Train auc 0.5278068362448943
# Valid auc 0.5248396201976133
# Valid aucroc: 0.5241476858887887
# CPU times: user 4min 5s, sys: 19.8 s, total: 4min 25s
# Wall time: 1min 52s
#
# ################################################################
# ########################### VAR 44 ##############################
# ################################################################
#
# ################### Fold 1 ########################
# 40001/40001 [==============================] - 0s 8us/step
# 159999/159999 [==============================] - 1s 7us/step
# Train auc 0.5476318540306022
# Valid auc 0.544788079833732
# ################### Fold 2 ########################
# 40001/40001 [==============================] - 0s 9us/step
# 159999/159999 [==============================] - 1s 8us/step
# Train auc 0.5434198405306632
# Valid auc 0.5535775653291863
# ################### Fold 3 ########################
# 40000/40000 [==============================] - 0s 10us/step
# 160000/160000 [==============================] - 1s 8us/step
# Train auc 0.5479114371547874
# Valid auc 0.54671282622463
# ################### Fold 4 ########################
# 39999/39999 [==============================] - 0s 9us/step
# 160001/160001 [==============================] - 1s 7us/step
# Train auc 0.5483682153903947
# Valid auc 0.5420539852321815
# ################### Fold 5 ########################
# 39999/39999 [==============================] - 0s 10us/step
# 160001/160001 [==============================] - 1s 9us/step
# Train auc 0.5469836556202967
# Valid auc 0.5451505086802115
# Valid aucroc: 0.5459195530332849
# CPU times: user 3min 12s, sys: 15.3 s, total: 3min 28s
# Wall time: 1min 31s
#
# VAR 45 Already calculated / VAR 46 Already calculated / VAR 47 Already calculated / VAR 48 Already calculated / VAR 49 Already calculated / VAR 50 Already calculated / VAR 51 Already calculated / VAR 52 Already calculated / VAR 53 Already calculated / VAR 54 Already calculated / VAR 55 Already calculated / VAR 56 Already calculated / VAR 57 Already calculated / VAR 58 Already calculated / VAR 59 Already calculated / VAR 60 Already calculated / VAR 61 Already calculated / VAR 62 Already calculated / VAR 63 Already calculated / VAR 64 Already calculated / VAR 65 Already calculated / VAR 66 Already calculated / VAR 67 Already calculated / VAR 68 Already calculated / VAR 69 Already calculated / VAR 70 Already calculated / VAR 71 Already calculated / VAR 72 Already calculated / ################################################################
# ########################### VAR 73 ##############################
# ################################################################
#
# ################### Fold 1 ########################
# 40001/40001 [==============================] - 0s 11us/step
# 159999/159999 [==============================] - 1s 8us/step
# Train auc 0.5044331714255349
# Valid auc 0.5131358299799189
# ################### Fold 2 ########################
# 40001/40001 [==============================] - 0s 10us/step
# 159999/159999 [==============================] - 1s 8us/step
# Train auc 0.5063827895764977
# Valid auc 0.5039149773768107
# ################### Fold 3 ########################
# 40000/40000 [==============================] - 0s 11us/step
# 160000/160000 [==============================] - 1s 9us/step
# Train auc 0.5029353467261006
# Valid auc 0.511605462819311
# ################### Fold 4 ########################
# 39999/39999 [==============================] - 0s 11us/step
# 160001/160001 [==============================] - 1s 9us/step
# Train auc 0.506160422180848
# Valid auc 0.5114992211121685
# ################### Fold 5 ########################
# 39999/39999 [==============================] - 0s 12us/step
# 160001/160001 [==============================] - 1s 9us/step
# Train auc 0.5012398355405866
# Valid auc 0.5093806054094634
# Valid aucroc: 0.5063827088679131
# CPU times: user 3min 34s, sys: 18.5 s, total: 3min 53s
# Wall time: 1min 45s
#
# ################################################################
# ########################### VAR 74 ##############################
# ################################################################
#
# ################### Fold 1 ########################
# 40001/40001 [==============================] - 0s 12us/step
# 159999/159999 [==============================] - 1s 9us/step
# Train auc 0.5209864472276574
# Valid auc 0.5254631659522901
# ################### Fold 2 ########################
# 40001/40001 [==============================] - 0s 12us/step
# 159999/159999 [==============================] - 1s 9us/step
# Train auc 0.5220137664603957
# Valid auc 0.5211717841409114
# ################### Fold 3 ########################
# 40000/40000 [==============================] - 1s 14us/step
# 160000/160000 [==============================] - 1s 9us/step
# Train auc 0.5215065101338676
# Valid auc 0.5195480283407863
# ################### Fold 4 ########################
# 39999/39999 [==============================] - 1s 13us/step
# 160001/160001 [==============================] - 2s 10us/step
# Train auc 0.5234197956261627
# Valid auc 0.5142844556726864
# ################### Fold 5 ########################
# 39999/39999 [==============================] - 1s 14us/step
# 160001/160001 [==============================] - 2s 10us/step
# Train auc 0.5199470618798075
# Valid auc 0.530352016775237
# Valid aucroc: 0.5204819291830163
# CPU times: user 4min 16s, sys: 20.7 s, total: 4min 37s
# Wall time: 2min 4s
#
# VAR 75 Already calculated / VAR 76 Already calculated / VAR 77 Already calculated / VAR 78 Already calculated / VAR 79 Already calculated / VAR 80 Already calculated / VAR 81 Already calculated / VAR 82 Already calculated / VAR 83 Already calculated / VAR 84 Already calculated / VAR 85 Already calculated / VAR 86 Already calculated / VAR 87 Already calculated / VAR 88 Already calculated / VAR 89 Already calculated / VAR 90 Already calculated / VAR 91 Already calculated / VAR 92 Already calculated / VAR 93 Already calculated / VAR 94 Already calculated / VAR 95 Already calculated / VAR 96 Already calculated / VAR 97 Already calculated / VAR 98 Already calculated / VAR 99 Already calculated / VAR 100 Already calculated / VAR 101 Already calculated / VAR 102 Already calculated / VAR 103 Already calculated / VAR 104 Already calculated / VAR 105 Already calculated / VAR 106 Already calculated / VAR 107 Already calculated / VAR 108 Already calculated / VAR 109 Already calculated / VAR 110 Already calculated / VAR 111 Already calculated / VAR 112 Already calculated / VAR 113 Already calculated / VAR 114 Already calculated / VAR 115 Already calculated / VAR 116 Already calculated / VAR 117 Already calculated / VAR 118 Already calculated / VAR 119 Already calculated / VAR 120 Already calculated / VAR 121 Already calculated / VAR 122 Already calculated / VAR 123 Already calculated / VAR 124 Already calculated / VAR 125 Already calculated / VAR 126 Already calculated / VAR 127 Already calculated / VAR 128 Already calculated / VAR 129 Already calculated / VAR 130 Already calculated / VAR 131 Already calculated / VAR 132 Already calculated / VAR 133 Already calculated / VAR 134 Already calculated / VAR 135 Already calculated / VAR 136 Already calculated / VAR 137 Already calculated / VAR 138 Already calculated / VAR 139 Already calculated / VAR 140 Already calculated / VAR 141 Already calculated / VAR 142 Already calculated / VAR 143 Already calculated / VAR 144 Already calculated / VAR 145 Already calculated / VAR 146 Already calculated / VAR 147 Already calculated / VAR 148 Already calculated / VAR 149 Already calculated / ################################################################
# ########################### VAR 150 ##############################
# ################################################################
#
# ################### Fold 1 ########################
# 40001/40001 [==============================] - 1s 15us/step
# 159999/159999 [==============================] - 2s 11us/step
# Train auc 0.5214083932528536
# Valid auc 0.5353740386198853
# ################### Fold 2 ########################
# 40001/40001 [==============================] - 1s 14us/step
# 159999/159999 [==============================] - 2s 11us/step
# Train auc 0.5223528422770816
# Valid auc 0.5233516383232112
# ################### Fold 3 ########################
# 40000/40000 [==============================] - 1s 15us/step
# 160000/160000 [==============================] - 2s 11us/step
# Train auc 0.5263674629641538
# Valid auc 0.5216994688868055
# ################### Fold 4 ########################
# 39999/39999 [==============================] - 1s 16us/step
# 160001/160001 [==============================] - 2s 11us/step
# Train auc 0.523286205425801
# Valid auc 0.5226974331624616
# ################### Fold 5 ########################
# 39999/39999 [==============================] - 1s 16us/step
# 160001/160001 [==============================] - 2s 11us/step
# Train auc 0.5232114703806705
# Valid auc 0.5254885666071154
# Valid aucroc: 0.5215335561521688
# CPU times: user 5min 31s, sys: 27.4 s, total: 5min 59s
# Wall time: 2min 41s
#
# ################################################################
# ########################### VAR 151 ##############################
# ################################################################
#
# ################### Fold 1 ########################
# 40001/40001 [==============================] - 1s 17us/step
# 159999/159999 [==============================] - 2s 11us/step
# Train auc 0.5265239203568922
# Valid auc 0.5228702378991896
# ################### Fold 2 ########################
# 40001/40001 [==============================] - 1s 17us/step
# 159999/159999 [==============================] - 2s 11us/step
# Train auc 0.5259445179752356
# Valid auc 0.5274127749291673
# ################### Fold 3 ########################
# 40000/40000 [==============================] - 1s 19us/step
# 160000/160000 [==============================] - 2s 12us/step
# Train auc 0.5259685944211059
# Valid auc 0.5243763844756208
# ################### Fold 4 ########################
# 39999/39999 [==============================] - 1s 17us/step
# 160001/160001 [==============================] - 2s 13us/step
# Train auc 0.524146925664162
# Valid auc 0.5265902160678966
# ################### Fold 5 ########################
# 39999/39999 [==============================] - 1s 18us/step
# 160001/160001 [==============================] - 2s 12us/step
# Train auc 0.5238944221051856
# Valid auc 0.5295976961019372
# Valid aucroc: 0.5233992309126397
# CPU times: user 4min 59s, sys: 23.6 s, total: 5min 23s
# Wall time: 2min 32s
#
# VAR 152 Already calculated / VAR 153 Already calculated / VAR 154 Already calculated / VAR 155 Already calculated / VAR 156 Already calculated / VAR 157 Already calculated / VAR 158 Already calculated / VAR 159 Already calculated / VAR 160 Already calculated / VAR 161 Already calculated / VAR 162 Already calculated / VAR 163 Already calculated / VAR 164 Already calculated / VAR 165 Already calculated / VAR 166 Already calculated / VAR 167 Already calculated / VAR 168 Already calculated / VAR 169 Already calculated / VAR 170 Already calculated / VAR 171 Already calculated / VAR 172 Already calculated / VAR 173 Already calculated / VAR 174 Already calculated / VAR 175 Already calculated / VAR 176 Already calculated / VAR 177 Already calculated / VAR 178 Already calculated / VAR 179 Already calculated / VAR 180 Already calculated / VAR 181 Already calculated / VAR 182 Already calculated / VAR 183 Already calculated / VAR 184 Already calculated / VAR 185 Already calculated / VAR 186 Already calculated / VAR 187 Already calculated / VAR 188 Already calculated / VAR 189 Already calculated / VAR 190 Already calculated / VAR 191 Already calculated / VAR 192 Already calculated / VAR 193 Already calculated / VAR 194 Already calculated / VAR 195 Already calculated / VAR 196 Already calculated / VAR 197 Already calculated / VAR 198 Already calculated / VAR 199 Already calculated /

# %%
var_ = 0
features = [f'var_{var_}', f'var_{var_}_FE']
X_train_unnorm = df_train[features].values
X_train = (X_train_unnorm - X_train_unnorm.mean(axis=0))/X_train_unnorm.std(axis=0)

# %%
mn,mx = X_train[:, 0].min(), X_train[:, 0].max()
mnFE = X_train[:, 1].min()
mxFE = X_train[:, 1].max()
step = 50
stepB = 15
x = df_grid['pred'].values
x = np.reshape(x,(stepB,step))
x = np.flip(x,axis=0)

# %%
sns.heatmap(x, cmap='RdBu_r', center=0.0) 
# plt.title(var_+' Predictions with Magic',fontsize=16)    
# plt.xticks(np.linspace(0,49,5),np.round(np.linspace(mn,mx,5),1))
# plt.xlabel('Var_'+str(var_))
# s = min(mxFE-mnFE+1,20)
# plt.yticks(np.linspace(mnFE,mxFE,s)-0.5,np.linspace(mxFE,mnFE,s).astype('int'))
# plt.ylabel('Count')
#plt.show()

# %%
from matplotlib import pyplot as plt
sns.heatmap(x, cmap='RdBu_r', center=0.0) 
# plt.title(var_+' Predictions with Magic',fontsize=16)    
# plt.xticks(np.linspace(0,49,5),np.round(np.linspace(mn,mx,5),1))
# plt.xlabel('Var_'+str(var_))
# s = min(mxFE-mnFE+1,20)
# plt.yticks(np.linspace(mnFE,mxFE,s)-0.5,np.linspace(mxFE,mnFE,s).astype('int'))
# plt.ylabel('Count')
plt.show()

# %%
df_grid
